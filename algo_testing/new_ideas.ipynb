# %%
import pandas as pd
from helpers.read_eco_data import preprocess
import matplotlib.pyplot as plt

# %%
df = preprocess('../esg_data/esg_data.json')
df = df.loc[df['eco_score'] > 0]
df = df.reset_index(drop=True)

# %%
print(df.head())
# Out:
#     ticker  eco_score
# 0  3MINDIA   0.163942
# 1   5PAISA   0.580448
# 2      AWL   0.219065
# 3     ATGL   0.255459
# 4  ADANIGR   0.050062

# %%
stocks = pd.DataFrame()

for stock_name in df['ticker']:
    try: 
        temp = pd.read_json(f'../data/{stock_name}.json')
        new_df = pd.DataFrame({'date' : temp['t'], f'{stock_name}_price': temp['c']})
        new_df['date'] = pd.to_datetime(new_df['date'], unit='s')

        if stocks.empty: 
            stocks = new_df
        else: 
            stocks = pd.merge(stocks, new_df, how = 'outer', on='date')
    except Exception as e: 
        print(f"*** error reading {stock_name} : ", e)
# Out:
# *** error reading ADANIGR :  File ../data/ADANIGR.json does not exist
# *** error reading ADANIT :  File ../data/ADANIT.json does not exist
# *** error reading ADYAF :  File ../data/ADYAF.json does not exist
# *** error reading AHLU :  File ../data/AHLU.json does not exist
# *** error reading ALBK :  File ../data/ALBK.json does not exist
# *** error reading ANDHRABANK :  File ../data/ANDHRABANK.json does not exist
# *** error reading APCO :  File ../data/APCO.json does not exist
# *** error reading AZRE :  File ../data/AZRE.json does not exist
# *** error reading CARE :  File ../data/CARE.json does not exist
# *** error reading  :  File ../data/.json does not exist
# *** error reading CORPBANK :  File ../data/CORPBANK.json does not exist
# *** error reading CRAFTSMA :  File ../data/CRAFTSMA.json does not exist
# *** error reading DELHIVER :  File ../data/DELHIVER.json does not exist
# *** error reading DLTA :  File ../data/DLTA.json does not exist
# *** error reading EQUITAS :  File ../data/EQUITAS.json does not exist
# *** error reading EQUITASB :  File ../data/EQUITASB.json does not exist
# *** error reading EROS :  File ../data/EROS.json does not exist
# *** error reading 1005Z :  File ../data/1005Z.json does not exist
# *** error reading FCON :  File ../data/FCON.json does not exist
# *** error reading CLPFF :  File ../data/CLPFF.json does not exist
# *** error reading GDL :  File ../data/GDL.json does not exist
# *** error reading GILL :  File ../data/GILL.json does not exist
# *** error reading GKO :  File ../data/GKO.json does not exist
# *** error reading GJGCF :  File ../data/GJGCF.json does not exist
# *** error reading HAPPSTMN :  File ../data/HAPPSTMN.json does not exist
# *** error reading HATH :  File ../data/HATH.json does not exist
# *** error reading ICRAF :  File ../data/ICRAF.json does not exist
# *** error reading IIFLWAM :  File ../data/IIFLWAM.json does not exist
# *** error reading ILFT :  File ../data/ILFT.json does not exist
# *** error reading  :  File ../data/.json does not exist
# *** error reading INOL :  File ../data/INOL.json does not exist
# *** error reading JPIN :  File ../data/JPIN.json does not exist
# *** error reading 522263 :  File ../data/522263.json does not exist
# *** error reading KALPATPOWR :  File ../data/KALPATPOWR.json does not exist
# *** error reading 532468 :  File ../data/532468.json does not exist
# *** error reading KNRC :  File ../data/KNRC.json does not exist
# *** error reading KWALITY :  File ../data/KWALITY.json does not exist
# *** error reading LANCI :  File ../data/LANCI.json does not exist
# *** error reading MAHINDCIE :  File ../data/MAHINDCIE.json does not exist
# *** error reading MANPASAND :  File ../data/MANPASAND.json does not exist
# *** error reading MAXHEALT :  File ../data/MAXHEALT.json does not exist
# *** error reading MAZDOCKS :  File ../data/MAZDOCKS.json does not exist
# *** error reading MERCATOR :  File ../data/MERCATOR.json does not exist
# *** error reading METROHL :  File ../data/METROHL.json does not exist
# *** error reading MOTHERSUMI :  File ../data/MOTHERSUMI.json does not exist
# *** error reading MUTH :  File ../data/MUTH.json does not exist
# *** error reading 534309 :  File ../data/534309.json does not exist
# *** error reading NILK :  File ../data/NILK.json does not exist
# *** error reading NIRMA :  File ../data/NIRMA.json does not exist
# *** error reading OBER :  File ../data/OBER.json does not exist
# *** error reading ORIENTBANK :  File ../data/ORIENTBANK.json does not exist
# *** error reading PARAG :  File ../data/PARAG.json does not exist
# *** error reading IX2 :  File ../data/IX2.json does not exist
# *** error reading RNAVAL :  File ../data/RNAVAL.json does not exist
# *** error reading PNCL :  File ../data/PNCL.json does not exist
# *** error reading DIAMOND :  File ../data/DIAMOND.json does not exist
# *** error reading PRINCPIP :  File ../data/PRINCPIP.json does not exist
# *** error reading PUNJLLOYD :  File ../data/PUNJLLOYD.json does not exist
# *** error reading 517522 :  File ../data/517522.json does not exist
# *** error reading  :  File ../data/.json does not exist
# *** error reading RMGB :  File ../data/RMGB.json does not exist
# *** error reading REPCO :  File ../data/REPCO.json does not exist
# *** error reading RITE :  File ../data/RITE.json does not exist
# *** error reading ROLEXRIN :  File ../data/ROLEXRIN.json does not exist
# *** error reading SISLTD :  File ../data/SISLTD.json does not exist
# *** error reading SHOP :  File ../data/SHOP.json does not exist
# *** error reading SCUF :  File ../data/SCUF.json does not exist
# *** error reading SPICEJET :  File ../data/SPICEJET.json does not exist
# *** error reading SREINFRA :  File ../data/SREINFRA.json does not exist
# *** error reading NA :  File ../data/NA.json does not exist
# *** error reading STARHEAL :  File ../data/STARHEAL.json does not exist
# *** error reading SUNCLAYLTD :  File ../data/SUNCLAYLTD.json does not exist
# *** error reading SUF :  File ../data/SUF.json does not exist
# *** error reading SYNDIBANK :  File ../data/SYNDIBANK.json does not exist
# *** error reading 519091 :  File ../data/519091.json does not exist
# *** error reading NA :  File ../data/NA.json does not exist
# *** error reading TCNSBR :  File ../data/TCNSBR.json does not exist
# *** error reading LAKSHVILAS :  File ../data/LAKSHVILAS.json does not exist

# %%
# find na count of each column 
to_be_dropped = stocks.isna().sum()

# %%
to_be_dropped.index
# Out:
# Index(['date', '3MINDIA_price', '5PAISA_price', 'AWL_price', 'ATGL_price',
#        'ADANIPORTS_price', 'ADANIPOWER_price', 'AEGISCHEM_price',
#        'ALLCARGO_price', 'AMARAJABAT_price',
#        ...
#        'TCIEXP_price', 'TEAMLEASE_price', 'TECHM_price', 'TECHNOE_price',
#        'TEJASNET_price', 'TEXRAIL_price', 'FEDERALBNK_price', 'KTKBANK_price',
#        'KARURVYSYA_price', 'THERMAX_price'],
#       dtype='object', length=295)

# %%
cleaned_stocks = stocks.drop(columns=[x for x in to_be_dropped.index if to_be_dropped[x] > 200])

# %%
cleaned_stocks = cleaned_stocks.dropna()

# %%
cleaned_stocks = cleaned_stocks.reset_index(drop=True)

# %%
cleaned_stocks
# Out:
#            date  3MINDIA_price  ADANIPORTS_price  ADANIPOWER_price  \
# 0    2011-03-09        3249.10            131.05            111.85
# 1    2011-03-10        3295.60            133.80            113.15
# 2    2011-03-11        3225.00            131.60            111.70
# 3    2011-03-14        3231.05            133.25            112.90
# 4    2011-03-15        3255.70            130.80            111.65
# ...         ...            ...               ...               ...
# 2574 2023-07-24       28280.85            735.30            238.00
# 2575 2023-07-31       28922.55            777.85            273.30
# 2576 2023-08-07       27407.55            791.40            273.30
# 2577 2023-08-14       28680.35            787.15            286.10
# 2578 2023-08-21       29034.20            858.15            324.85
#
#       AEGISCHEM_price  ALLCARGO_price  AMARAJABAT_price  ANANTRAJ_price  \
# 0               28.80           57.37             86.25           78.95
# 1               28.60           57.31             85.00           77.65
# 2               28.55           58.33             85.58           76.25
# 3               28.80           59.04             85.78           77.00
# 4               28.72           58.33             86.60           74.50
# ...               ...             ...               ...             ...
# 2574           368.05          296.40            625.05          189.80
# 2575           382.00          312.05            634.85          201.65
# 2576           376.30          304.90            626.70          197.25
# 2577           364.55          284.30            613.50          189.60
# 2578           349.95          268.50            627.80          202.40
#
#       APOLLOTYRE_price  ASAHIINDIA_price  ...  TATAINVEST_price  \
# 0                64.45             77.40  ...            499.05
# 1                65.90             78.00  ...            508.10
# 2                66.40             76.38  ...            504.20
# 3                67.80             79.10  ...            502.70
# 4                69.00             75.65  ...            496.70
# ...                ...               ...  ...               ...
# 2574            414.70            564.90  ...           2354.90
# 2575            432.80            573.75  ...           2527.80
# 2576            434.85            530.95  ...           2529.65
# 2577            399.50            509.80  ...           2457.35
# 2578            398.80            493.60  ...           2449.05
#
#       TATAMOTORS_price  TATAPOWER_price  TTML_price  TECHM_price  \
# 0               230.19           118.87       14.75       183.49
# 1               230.53           115.90       14.99       182.08
# 2               230.05           116.17       14.65       182.60
# 3               232.66           120.69       14.70       184.55
# 4               226.00           116.85       14.41       183.71
# ...                ...              ...         ...          ...
# 2574            629.25           217.35       79.60      1161.85
# 2575            644.30           236.70       79.10      1115.50
# 2576            609.50           232.80       78.45      1183.65
# 2577            607.35           231.15       76.90      1219.75
# 2578            620.50           239.35       75.70      1218.85
#
#       TEXRAIL_price  FEDERALBNK_price  KTKBANK_price  KARURVYSYA_price  \
# 0             62.92             38.02          82.67             67.29
# 1             60.56             37.45          81.19             66.49
# 2             60.11             36.52          79.31             67.02
# 3             60.84             36.50          77.71             66.83
# 4             57.93             36.13          75.97             67.06
# ...             ...               ...            ...               ...
# 2574          96.15            133.95         207.15            129.35
# 2575         106.65            135.65         208.35            123.95
# 2576         107.80            134.05         215.40            124.30
# 2577         115.50            133.00         225.85            121.55
# 2578         117.85            134.25         228.90            120.75
#
#       THERMAX_price
# 0            607.35
# 1            600.10
# 2            606.50
# 3            600.10
# 4            597.15
# ...             ...
# 2574        2447.25
# 2575        2599.70
# 2576        2511.55
# 2577        2563.55
# 2578        2766.50
#
# [2579 rows x 202 columns]

# %%
cleaned_stocks.to_csv('../esg_data/cleaned_stocks.csv', index=False)

# %%
cleaned_stocks_dates = cleaned_stocks.date.to_list()

# %%
# Out:
# [Timestamp('2011-03-09 00:00:00'), Timestamp('2011-03-10 00:00:00'), Timestamp('2011-03-11 00:00:00'), Timestamp('2011-03-14 00:00:00'), Timestamp('2011-03-15 00:00:00'), Timestamp('2011-03-16 00:00:00'), Timestamp('2011-03-18 00:00:00'), Timestamp('2011-03-21 00:00:00'), Timestamp('2011-03-24 00:00:00'), Timestamp('2011-03-25 00:00:00'), Timestamp('2011-03-28 00:00:00'), Timestamp('2011-03-29 00:00:00'), Timestamp('2011-03-30 00:00:00'), Timestamp('2011-03-31 00:00:00'), Timestamp('2011-04-04 00:00:00'), Timestamp('2011-04-05 00:00:00'), Timestamp('2011-04-07 00:00:00'), Timestamp('2011-04-08 00:00:00'), Timestamp('2011-04-11 00:00:00'), Timestamp('2011-04-18 00:00:00'), Timestamp('2011-04-19 00:00:00'), Timestamp('2011-04-21 00:00:00'), Timestamp('2011-04-26 00:00:00'), Timestamp('2011-04-27 00:00:00'), Timestamp('2011-04-28 00:00:00'), Timestamp('2011-04-29 00:00:00'), Timestamp('2011-05-06 00:00:00'), Timestamp('2011-05-09 00:00:00'), Timestamp('2011-05-10 00:00:00'), Timestamp('2011-05-11 00:00:00'), Timestamp('2011-05-13 00:00:00'), Timestamp('2011-05-16 00:00:00'), Timestamp('2011-05-17 00:00:00'), Timestamp('2011-05-18 00:00:00'), Timestamp('2011-05-19 00:00:00'), Timestamp('2011-05-20 00:00:00'), Timestamp('2011-05-23 00:00:00'), Timestamp('2011-05-25 00:00:00'), Timestamp('2011-05-26 00:00:00'), Timestamp('2011-05-27 00:00:00'), Timestamp('2011-05-31 00:00:00'), Timestamp('2011-06-01 00:00:00'), Timestamp('2011-06-02 00:00:00'), Timestamp('2011-06-03 00:00:00'), Timestamp('2011-06-06 00:00:00'), Timestamp('2011-06-07 00:00:00'), Timestamp('2011-06-08 00:00:00'), Timestamp('2011-06-09 00:00:00'), Timestamp('2011-06-10 00:00:00'), Timestamp('2011-06-13 00:00:00'), Timestamp('2011-06-14 00:00:00'), Timestamp('2011-06-15 00:00:00'), Timestamp('2011-06-16 00:00:00'), Timestamp('2011-06-17 00:00:00'), Timestamp('2011-06-20 00:00:00'), Timestamp('2011-06-21 00:00:00'), Timestamp('2011-06-22 00:00:00'), Timestamp('2011-06-23 00:00:00'), Timestamp('2011-06-24 00:00:00'), Timestamp('2011-06-27 00:00:00'), Timestamp('2011-06-28 00:00:00'), Timestamp('2011-06-29 00:00:00'), Timestamp('2011-06-30 00:00:00'), Timestamp('2011-07-01 00:00:00'), Timestamp('2011-07-04 00:00:00'), Timestamp('2011-07-05 00:00:00'), Timestamp('2011-07-06 00:00:00'), Timestamp('2011-07-07 00:00:00'), Timestamp('2011-07-11 00:00:00'), Timestamp('2011-07-18 00:00:00'), Timestamp('2011-07-19 00:00:00'), Timestamp('2011-07-20 00:00:00'), Timestamp('2011-07-21 00:00:00'), Timestamp('2011-07-22 00:00:00'), Timestamp('2011-07-25 00:00:00'), Timestamp('2011-07-26 00:00:00'), Timestamp('2011-07-27 00:00:00'), Timestamp('2011-07-28 00:00:00'), Timestamp('2011-07-29 00:00:00'), Timestamp('2011-08-01 00:00:00'), Timestamp('2011-08-02 00:00:00'), Timestamp('2011-08-03 00:00:00'), Timestamp('2011-08-04 00:00:00'), Timestamp('2011-08-05 00:00:00'), Timestamp('2011-08-08 00:00:00'), Timestamp('2011-08-09 00:00:00'), Timestamp('2011-08-10 00:00:00'), Timestamp('2011-08-11 00:00:00'), Timestamp('2011-08-17 00:00:00'), Timestamp('2011-08-18 00:00:00'), Timestamp('2011-08-19 00:00:00'), Timestamp('2011-08-25 00:00:00'), Timestamp('2011-08-29 00:00:00'), Timestamp('2011-09-02 00:00:00'), Timestamp('2011-09-05 00:00:00'), Timestamp('2011-09-07 00:00:00'), Timestamp('2011-09-08 00:00:00'), Timestamp('2011-09-09 00:00:00'), Timestamp('2011-09-12 00:00:00'), Timestamp('2011-09-13 00:00:00'), Timestamp('2011-09-14 00:00:00'), Timestamp('2011-09-16 00:00:00'), Timestamp('2011-09-19 00:00:00'), Timestamp('2011-09-20 00:00:00'), Timestamp('2011-09-21 00:00:00'), Timestamp('2011-09-23 00:00:00'), Timestamp('2011-09-26 00:00:00'), Timestamp('2011-09-27 00:00:00'), Timestamp('2011-09-28 00:00:00'), Timestamp('2011-09-29 00:00:00'), Timestamp('2011-09-30 00:00:00'), Timestamp('2011-10-03 00:00:00'), Timestamp('2011-10-17 00:00:00'), Timestamp('2011-10-19 00:00:00'), Timestamp('2011-10-21 00:00:00'), Timestamp('2011-10-25 00:00:00'), Timestamp('2011-10-28 00:00:00'), Timestamp('2011-11-03 ...
